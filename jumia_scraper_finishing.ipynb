# %%
import pandas as pd

# %%
df=pd.read_csv("jumia_details.csv")
df.head()
# Out:
#                                                    0  \
# 0  Fingerprint Touch Noise- Cancellation Stereo B...
# 1                                          GH₵ 27.84
# 2                                     GH₵ 51.00\n45%
# 3                                3.8 out of 5\n(216)
#
#                                              1  \
# 0  Wireless Pods 13 Bluetooth Earphone - Black
# 1                                    GH₵ 33.60
# 2                               GH₵ 69.00\n51%
# 3                          3.9 out of 5\n(257)
#
#                                      2  \
# 0  IOOIOO F9 Bluetooth Earbuds - Black
# 1                            GH₵ 59.00
# 2                      GH₵ 116.00\n49%
# 3                  4.2 out of 5\n(233)
#
#                                                    3  \
# 0  Bluetooth 5.0 Wireless Headsets 10D Stereo Hea...
# 1                                          GH₵ 32.00
# 2                                     GH₵ 56.00\n43%
# ...

# %%
jumia=df.transpose()

# %%
jumia.head()
# Out:
#                                                    0          1  \
# 0  Fingerprint Touch Noise- Cancellation Stereo B...  GH₵ 27.84
# 1        Wireless Pods 13 Bluetooth Earphone - Black  GH₵ 33.60
# 2                IOOIOO F9 Bluetooth Earbuds - Black  GH₵ 59.00
# 3  Bluetooth 5.0 Wireless Headsets 10D Stereo Hea...  GH₵ 32.00
# 4  PRO6 Bluetooth Headsets sport Headphones Charg...  GH₵ 49.00
#
#                  2                    3
# 0   GH₵ 51.00\n45%  3.8 out of 5\n(216)
# 1   GH₵ 69.00\n51%  3.9 out of 5\n(257)
# 2  GH₵ 116.00\n49%  4.2 out of 5\n(233)
# 3   GH₵ 56.00\n43%    4 out of 5\n(104)
# 4   GH₵ 96.00\n49%   4.3 out of 5\n(23)

# %%
jumia.columns=['name','price','old_price','rating']


jumia.head(20)
# Out:
#                                                  name       price  \
# 0   Fingerprint Touch Noise- Cancellation Stereo B...   GH₵ 27.84
# 1         Wireless Pods 13 Bluetooth Earphone - Black   GH₵ 33.60
# 2                 IOOIOO F9 Bluetooth Earbuds - Black   GH₵ 59.00
# 3   Bluetooth 5.0 Wireless Headsets 10D Stereo Hea...   GH₵ 32.00
# 4   PRO6 Bluetooth Headsets sport Headphones Charg...   GH₵ 49.00
# 5   In-Ear Touchscreen Bluetooth Headset Wireless ...   GH₵ 47.04
# 6   F9 Bluetooth Wireless Earphone Earbuds For Sam...   GH₵ 62.00
# 7                        Bluetooth Wireless Earphones   GH₵ 40.74
# 8   Pro6 Wireless Earphone Earbuds Bluetooth 5.0 F...   GH₵ 62.00
# 9                       Bluetooth Earphone V5.0-Black   GH₵ 29.00
# 10  PRO2 Wireless Earbuds, Bluetooth 5.0 Headset E...   GH₵ 29.00
# 11  Hbs730 Neck Wear Type Bluetooth HiFi Wireless ...   GH₵ 58.00
# 12  TWS Mini Air Wireless Bluetooth Ear Pods Pro 4...   GH₵ 50.00
# ...
